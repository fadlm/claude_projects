# %% [markdown]
# # Catholic University of Rwanda (CUR)
#
# ## Python for Data Analysis
#
# **Lecturer:** Fadl Musa
#
# **August 2026**

# %% [markdown]
# ## Loading Python Libraries

# %%
# Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.axis([0, 6, 0, 20])
plt.show()

# %%
a = np.array([10, 20, 30])
b = np.array([1, 2, 3])

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: [11 22 33]
# Subtraction: [ 9 18 27]
# Multiplication: [10 40 90]
# Division: [10. 10. 10.]

# %%
arr = np.array([10, 20, 30, 40])

print("First element:", arr[0])
print("Last element:", arr[-1])
# Out:
# First element: 10
# Last element: 40

# %%
arr = np.array([10, 20, 30, 40, 50])

print("Slice (1 to 3):", arr[1:4])
print("First three elements:", arr[:3])
# Out:
# Slice (1 to 3): [20 30 40]
# First three elements: [10 20 30]

# %% [markdown]
# Broadcasting allows operations between arrays of different shapes without explicitly resizing them, improving efficiency and reducing code complexity.

# %%
arr = np.array([1, 2, 3])

print("Add scalar:", arr + 5)

b = np.array([[1], [2], [3]])
c = np.array([10, 20, 30])

print("Broadcasting result:\n", b + c)
# Out:
# Add scalar: [6 7 8]
# Broadcasting result:
#  [[11 21 31]
#  [12 22 32]
#  [13 23 33]]

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.axis([0, 6, 0, 20])
plt.show()

# %%
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["target"] = iris.target

counts = df["target"].value_counts()

plt.bar(counts.index, counts.values)
plt.title("Bar Chart (Iris Dataset)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# A histogram is used to show the distribution of data by grouping values into bins (ranges). The X-axis represents the bins, and the Y-axis shows the frequency of values in each bin.

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

plt.hist(df["sepal length (cm)"], bins=10)
plt.title("Histogram (Iris Dataset)")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them. The scatter() method in the matplotlib library is used to draw a scatter plot

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = iris.target

plt.scatter(df["sepal length (cm)"], df["sepal width (cm)"])

plt.title("Scatter Plot (Iris Dataset)")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")

plt.show()

# %% [markdown]
# Seaborn is a high level visualization library built on Matplotlib that provides more attractive and informative statistical plots.

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = iris.target

sns.scatterplot(x="sepal length (cm)", y="sepal width (cm)", hue="species", data=df)

plt.title("Seaborn Scatter Plot")
plt.show()

# %% [markdown]
# *Press Shift+Enter to execute the Jupyter cell*

# %%
df = pd.read_csv("Salaries.csv")

# %% [markdown]
# ## Reading data using pandas

# %% [markdown]
# **Note:** The above command has many optional arguments to fine-tune the data import process.
#
# There are a number of pandas commands to read other data formats:

# %%
pd.read_excel('myfile.xlsx', sheet_name='Sheet1', index_col=None, na_values=['NA'])
pd.read_stata('myfile.dta')
pd.read_sas('myfile.sas7bdat')
pd.read_hdf('myfile.h5', 'df')

# %% [markdown]
# ## Exploring data frames

# %%
# List first 5 records
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#      Year  Notes         Agency  Status
# ...

# %%
# List last 10 recors
df.tail(10)
# Out:
#           Id       EmployeeName                      JobTitle  BasePay  \
# 69120  69121      Karen Napitan                 Special Nurse  7823.40
# 69121  69122  Francisco Jimenez             Recreation Leader  8763.12
# 69122  69123  Dominique Hoskins             Recreation Leader  8645.17
# 69123  69124   Florence Corteza        Public Service Trainee  8850.00
# 69124  69125            Van Lee              Transit Operator  6523.62
# 69125  69126      Luranda Brown         School Crossing Guard  8688.48
# 69126  69127  Jonathan Petierre                 Special Nurse  6647.27
# 69127  69128        Perry Blunt  Public Svc Aide-Public Works  8558.77
# 69128  69129   Angel Colon Chin             Recreation Leader  8809.31
# 69129  69130   Larry Antenorcru                           NaN      NaN
#
#        OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits    Year  \
# 69120         0.00      0.00   1718.20   7823.40           9541.60  2012.0
# ...

# %% [markdown]
# *Output: a table showing the first 5 records of the dataset.*

# %% [markdown]
# ## Hands-on Exercises
#
# - Try to read the first 10, 20, 50 records
# - Can you guess how to view the last few records? *(Hint: there's a `tail()` method, similar to `head()`)*

# %%
# Try it here

# %% [markdown]
# ## Data Frame data types
#
# | Pandas Type | Native Python Type | Description |
# | --- | --- | --- |
# | object | string | The most general dtype. Will be assigned to your column if the column has mixed types (numbers and strings). |
# | int64 | int | Numeric characters. 64 refers to the memory allocated to hold this character. |
# | float64 | float | Numeric characters with decimals. If a column contains numbers and NaNs (see below), pandas will default to float64, in case your missing value has a decimal. |
# | datetime64, timedelta[ns] | N/A (but see the `datetime` module in Python's standard library) | Values meant to hold time data. Look into these for time series experiments. |

# %% [markdown]
# ## Data Frame data types

# %%
# Check a particular column type
df['salary'].dtype

# %% [markdown]
# `Out: dtype('int64')`

# %%
# Check types for all the columns
df.dtypes

# %% [markdown]
# ```
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object
# ```

# %% [markdown]
# ## Data Frames attributes
#
# Python objects have attributes and methods.
#
# | df.attribute | description |
# | --- | --- |
# | dtypes | list the types of the columns |
# | columns | list the column names |
# | axes | list the row labels and column names |
# | ndim | number of dimensions |
# | size | number of elements |
# | shape | return a tuple representing the dimensionality |
# | values | numpy representation of the data |

# %% [markdown]
# ## Hands-on Exercises
#
# - Find how many records this data frame has
# - How many elements are there?
# - What are the column names?
# - What types of columns do we have in this data frame?

# %%
# Try it here

# %% [markdown]
# ## Data Frames methods
#
# Unlike attributes, Python methods have parentheses. All attributes and methods can be listed with the `dir()` function: `dir(df)`
#
# | df.method() | description |
# | --- | --- |
# | head( [n] ), tail( [n] ) | first/last n rows |
# | describe() | generate descriptive statistics (for numeric columns only) |
# | max(), min() | return max/min values for all numeric columns |
# | mean(), median() | return mean/median values for all numeric columns |
# | std() | standard deviation |
# | sample([n]) | returns a random sample of the data frame |
# | dropna() | drop all the records with missing values |

# %% [markdown]
# ## Hands-on Exercises
#
# - Give the summary for the numeric columns in the dataset
# - Calculate standard deviation for all numeric columns
# - What are the mean values of the first 50 records in the dataset? *(Hint: use the `head()` method to subset the first 50 records and then calculate the mean)*

# %%
# Try it here

# %% [markdown]
# ## Selecting a column in a Data Frame

# %% [markdown]
# **Method 1:** Subset the data frame using the column name:

# %%
df['sex']

# %% [markdown]
# **Method 2:** Use the column name as an attribute:

# %%
df.sex

# %% [markdown]
# **Note:** there is an attribute `rank` for pandas data frames, so to select a column named `"rank"` we should use Method 1.

# %% [markdown]
# ## Hands-on Exercises
#
# - Calculate the basic statistics for the salary column
# - Find how many values are in the salary column (use the `count` method)
# - Calculate the average salary

# %%
# Try it here

# %% [markdown]
# ## Data Frames `groupby` method
#
# Using the "group by" method we can:
# - Split the data into groups based on some criteria
# - Calculate statistics (or apply a function) to each group
#
# Similar to the `dplyr()` function in R.

# %%
# Group data using rank
df_rank = df.groupby(['rank'])

# %%
# Calculate mean value for each numeric column per each group
df_rank.mean()

# %% [markdown]
# ## Data Frames `groupby` method

# %% [markdown]
# Once the groupby object is created we can calculate various statistics for each group:

# %%
# Calculate mean salary for each professor rank:
df.groupby('rank')[['salary']].mean()

# %% [markdown]
# **Note:** If single brackets are used to specify the column (e.g. `salary`), then the output is a Pandas `Series` object. When double brackets are used the output is a `DataFrame`.

# %% [markdown]
# ## Data Frames `groupby` method
#
# `groupby` performance notes:
# - No grouping/splitting occurs until it's needed. Creating the groupby object only verifies that you have passed a valid mapping.
# - By default the group keys are sorted during the groupby operation. You may want to pass `sort=False` for a potential speedup:

# %%
# Calculate mean salary for each professor rank:
df.groupby(['rank'], sort=False)[['salary']].mean()

# %% [markdown]
# ## Data Frame: filtering
#
# To subset the data we can apply Boolean indexing. This is commonly known as a filter. For example, if we want to subset the rows in which the salary value is greater than \$120K:

# %%
# Calculate mean salary for each professor rank:
df_sub = df[df['salary'] > 120000]

# %% [markdown]
# Any Boolean operator can be used to subset the data:
#
# - `>` greater; `>=` greater or equal
# - `<` less; `<=` less or equal
# - `==` equal; `!=` not equal

# %%
# Select only those rows that contain female professors:
df_f = df[df['sex'] == 'Female']

# %% [markdown]
# ## Data Frames: Slicing
#
# There are a number of ways to subset the Data Frame:
# - One or more columns
# - One or more rows
# - A subset of rows and columns
#
# Rows and columns can be selected by their position or label.

# %% [markdown]
# ## Data Frames: Slicing

# %% [markdown]
# When selecting one column, it is possible to use a single set of brackets, but the resulting object will be a `Series` (not a `DataFrame`):

# %%
# Select column salary:
df['salary']

# %% [markdown]
# When we need to select more than one column and/or make the output a `DataFrame`, we should use double brackets:

# %%
# Select columns rank and salary:
df[['rank', 'salary']]

# %% [markdown]
# ## Data Frames: Selecting rows

# %% [markdown]
# If we need to select a range of rows, we can specify the range using `":"`:

# %%
# Select rows by their position:
df[10:20]

# %% [markdown]
# Notice that the first row has position 0, and the last value in the range is omitted: so for the `0:10` range, the first 10 rows are returned with positions starting at 0 and ending at 9.

# %% [markdown]
# ## Data Frames: method `loc`

# %% [markdown]
# If we need to select a range of rows using their labels, we can use the `loc` method:

# %%
# Select rows by their labels:
df_sub.loc[10:20, ['rank', 'sex', 'salary']]

# %% [markdown]
# ## Data Frames: method `iloc`

# %% [markdown]
# If we need to select a range of rows and/or columns using their positions, we can use the `iloc` method:

# %%
# Select rows and columns by position:
df_sub.iloc[10:20, [0, 3, 4, 5]]

# %% [markdown]
# ## Data Frames: method `iloc` (summary)

# %%
df.iloc[0]      # First row of a data frame
df.iloc[i]      # (i+1)th row
df.iloc[-1]     # Last row

df.iloc[:, 0]   # First column
df.iloc[:, -1]  # Last column

df.iloc[0:7]          # First 7 rows
df.iloc[:, 0:2]       # First 2 columns
df.iloc[1:3, 0:2]     # Second through third rows and first 2 columns
df.iloc[[0, 5], [1, 3]]  # 1st and 6th rows and 2nd and 4th columns

# %% [markdown]
# ## Data Frames: Sorting

# %% [markdown]
# We can sort the data by a value in a column. By default the sorting occurs in ascending order and a new data frame is returned.

# %%
# Create a new data frame from the original, sorted by the column 'service'
df_sorted = df.sort_values(by='service')
df_sorted.head()

# %% [markdown]
# ## Data Frames: Sorting

# %% [markdown]
# We can sort the data using two or more columns:

# %%
df_sorted = df.sort_values(by=['service', 'salary'], ascending=[True, False])
df_sorted.head(10)

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Missing values are marked as `NaN`.

# %%
# Read a dataset with missing values
flights = pd.read_csv("Salaries.csv")

# %%
# Select the rows that have at least one missing value
flights[flights.isnull().any(axis=1)].head()

# %% [markdown]
# ## Missing Values
#
# There are a number of methods to deal with missing values in the data frame:
#
# | df.method() | description |
# | --- | --- |
# | dropna() | Drop missing observations |
# | dropna(how='all') | Drop observations where all cells are NA |
# | dropna(axis=1, how='all') | Drop column if all the values are missing |
# | dropna(thresh=5) | Drop rows that contain fewer than 5 non-missing values |
# | fillna(0) | Replace missing values with zeros |
# | isnull() | Returns True if the value is missing |
# | notnull() | Returns True for non-missing values |

# %% [markdown]
# ## Missing Values
#
# - When summing the data, missing values will be treated as zero.
# - If all values are missing, the sum will be equal to `NaN`.
# - `cumsum()` and `cumprod()` methods ignore missing values but preserve them in the resulting arrays.
# - Missing values in the `GroupBy` method are excluded (just like in R).
# - Many descriptive statistics methods have a `skipna` option to control whether missing data should be excluded. This value is set to `True` by default (unlike R).

# %% [markdown]
# ## Aggregation Functions in Pandas
#
# Aggregation — computing a summary statistic about each group, i.e.:
# - Compute group sums or means
# - Compute group sizes/counts
#
# Common aggregation functions:
# - `min`, `max`
# - `count`, `sum`, `prod`
# - `mean`, `median`, `mode`, `mad`
# - `std`, `var`

# %% [markdown]
# ## Aggregation Functions in Pandas

# %% [markdown]
# The `agg()` method is useful when multiple statistics are computed per column:

# %%
flights[['dep_delay', 'arr_delay']].agg(['min', 'mean', 'max'])

# %%
df.describe()
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  \
# count  69130.000000   69129.000000   69129.000000   69129.000000
# mean   34565.500000   67898.089460    5038.418889    3821.773245
# std    19956.256392   39631.160255   11223.069911    8120.201439
# min        1.000000       0.000000       0.000000       0.000000
# 25%    17283.250000   42612.200000       0.000000       5.400000
# 50%    34565.500000   65299.400000       0.000000    1024.960000
# 75%    51847.750000   94063.210000    4910.390000    4505.140000
# max    69130.000000  302578.000000  245131.880000  400184.250000
#
#            Benefits       TotalPay  TotalPayBenefits          Year  Notes  \
# count  32970.000000   69129.000000      69129.000000  69129.000000    0.0
# mean   29424.558051   76758.281594      90791.866326   2011.476934    NaN
# std    13635.290587   46960.861060      56158.091647      0.499471    NaN
# min        0.000000       0.000000          0.000000   2011.000000    NaN
# ...
